# %%
import numpy as np
import matplotlib.cm as cmap
import time
import os.path
import scipy
import pickle as pickle
from struct import unpack
from brian2 import *
import brian2
from brian2tools import *
from PIL import Image
# Out:
# C:\Users\Lahiru Sampath\Anaconda3\envs\sim\lib\site-packages\ipykernel\parentpoller.py:116: UserWarning: Parent poll failed.  If the frontend dies,
#                 the kernel may be left running.  Please let us know
#                 about your system (bitness, Python, etc.) at
#                 ipython-dev@scipy.org
#   ipython-dev@scipy.org""")

# %% [markdown]
# # FUNCTIONS

# %%
def edge_detection_kernel(img):
    source = np.copy(img)
    y = source.shape[0]
    x = source.shape[1]

    v_filter = np.array([[1,1,1], [1,0,1], [1,1,1]])
    h_filter = np.array([[0,0,0], [0,1,0], [0,0,0]])

    h_result = np.zeros((y,x))
    v_result = np.zeros((y,x))
    for i in range(1, y-1):
        for j in range(1, x-1):
            local = np.copy(source[i-1:i+2, j-1:j+2])
            h_result[i][j] = np.sum(local*h_filter)
            v_result[i][j] = np.sum(local*v_filter)
            
        
    v_result_ab = np.absolute(v_result)
    v_result_ab_f = v_result_ab - np.min(v_result_ab)
    
    h_result_ab = np.absolute(h_result)
    h_result_ab_f = h_result_ab - np.min(h_result_ab)
   
    return (v_result_ab_f, h_result_ab_f)

# %% [markdown]
# # CODE

# %%
stimuli_file = './pic_300.tif'

fig_num = 1

# %%
img = Image.open(stimuli_file)
img.load()
img_arr = np.asarray(img, dtype="int32")
stimuli = np.absolute(img_arr - 255)/4     # 28,28 grid values from 0 to 63.75

fig = figure(fig_num, figsize = (10, 10))
im2 = imshow(stimuli, vmin = np.min(stimuli), vmax = np.max(stimuli) , cmap = cmap.get_cmap('hot_r'))
colorbar(im2)
fig_num += 1

# %%
v_edge_stimuli, h_edge_stimuli = edge_detection_kernel(stimuli) 

fig = figure(fig_num, figsize = (10, 10))
im2 = imshow(v_edge_stimuli, vmin = np.min(v_edge_stimuli), vmax = np.max(v_edge_stimuli) , cmap = cmap.get_cmap('hot_r'))
colorbar(im2)
fig_num += 1

fig = figure(fig_num, figsize = (10, 10))
im2 = imshow(h_edge_stimuli, vmin = np.min(h_edge_stimuli), vmax = np.max(h_edge_stimuli) , cmap = cmap.get_cmap('hot_r'))
colorbar(im2)
fig_num += 1

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-4b48460328ce> in <module>
# ----> 1 np.zeros((y,x))
#
# NameError: name 'y' is not defined

# %%
# source = np.copy(stimuli)
# maxx = np.max(source)
# minn = np.min(source)
# s_max = 20
# s_min = 0
# c_max = 200
# c_min = 0

# y = stimuli.shape[0]
# x = stimuli.shape[1]

# for i in range(y-2):
#     for j in range(x-2):
#         local = np.copy(source[i:i+3, j:j+3])
#         center = local[1][1]
#         surround = s_min + np.absolute(local-maxx)*(s_max-s_min)/(maxx-minn)
#         total = np.sum(surround)-surround[1][1] + center
#         source[i+1][j+1] = total/9
#         surround[1][1] = center
#         print(surround)
# Out:
# [[20.         20.         20.        ]
#  [20.          0.         20.        ]
#  [20.         20.          6.98039216]]
# [[20.         20.         20.        ]
#  [14.87650049  0.         20.        ]
#  [20.          6.98039216  6.98039216]]
# [[20.         20.         20.        ]
#  [15.50893996  0.         20.        ]
#  [ 6.98039216  6.98039216  6.98039216]]
# [[20.         20.         20.        ]
#  [15.94073668  0.         20.        ]
#  [ 6.98039216  6.98039216  6.98039216]]
# [[20.         20.         20.        ]
#  [15.92568494  0.         20.        ]
#  [ 6.98039216  6.98039216  6.98039216]]
# [[20.         20.         20.        ]
#  [15.92620962  0.         20.        ]
#  [ 6.98039216  6.98039216  6.98039216]]
# [[20.         20.         20.        ]
#  [15.92619133  0.         20.        ]
#  [ 6.98039216  6.98039216 20.        ]]
# [[20.         20.         20.        ]
#  [15.47234943  0.         20.        ]
#  [ 6.98039216 20.         20.        ]]
# [[20.         14.87650049 15.50893996]
#  [20.          0.          6.98039216]
#  [20.         20.          6.98039216]]
# [[14.87650049 15.50893996 15.94073668]
#  [15.66549108 41.5         6.98039216]
#  [20.          6.98039216  6.98039216]]
# [[15.50893996 15.94073668 15.92568494]
#  [14.96530389 41.5         6.98039216]
#  [ 6.98039216  6.98039216  6.98039216]]
# [[15.94073668 15.92568494 15.92620962]
#  [15.40698095 41.5         6.98039216]
#  [ 6.98039216  6.98039216  6.98039216]]
# [[15.92568494 15.92620962 15.92619133]
#  [15.37703945 41.5         6.98039216]
#  [ 6.98039216  6.98039216  6.98039216]]
# [[15.92620962 15.92619133 15.47234943]
#  [15.37859019 41.5         6.98039216]
#  [ 6.98039216  6.98039216  6.98039216]]
# [[15.92619133 15.47234943 15.03432709]
#  [15.39433868 41.5        20.        ]
#  [ 6.98039216  6.98039216 20.        ]]
# [[15.47234943 15.03432709 20.        ]
#  [14.51719422  0.         20.        ]
#  [ 6.98039216 20.         20.        ]]
# [[20.         15.66549108 14.96530389]
#  [20.          0.          6.98039216]
#  [20.         20.         20.        ]]
# [[15.66549108 14.96530389 15.40698095]
#  [15.20309587 41.5         6.98039216]
#  [20.         20.         20.        ]]
# [[14.96530389 15.40698095 15.37703945]
#  [14.08379036 41.5         6.98039216]
#  [20.         20.         20.        ]]
# [[15.40698095 15.37703945 15.37859019]
#  [14.13286251 41.5         6.98039216]
#  [20.         20.         20.        ]]
# [[15.37703945 15.37859019 15.39433868]
#  [14.11674544 41.5         6.98039216]
#  [20.         20.         20.        ]]
# [[15.37859019 15.39433868 14.51719422]
#  [14.11774794 41.5         6.98039216]
#  [20.         20.         20.        ]]
# [[15.39433868 14.51719422 15.39854421]
#  [14.14768581 41.5        20.        ]
#  [20.         20.         20.        ]]
# [[14.51719422 15.39854421 20.        ]
#  [13.69210412  0.         20.        ]
#  [20.         20.         20.        ]]
# [[20.         15.20309587 14.08379036]
#  [20.          0.         20.        ]
#  [20.         20.         20.        ]]
# [[15.20309587 14.08379036 14.13286251]
#  [14.79609983  0.         20.        ]
#  [20.         20.         20.        ]]
# [[14.08379036 14.13286251 14.11674544]
#  [15.18201835  0.         20.        ]
#  [20.         20.         20.        ]]
# [[14.13286251 14.11674544 14.11774794]
#  [15.20643428  0.         20.        ]
#  [20.         20.         20.        ]]
# [[14.11674544 14.11774794 14.14768581]
#  [15.20439947  0.         20.        ]
#  [20.         20.         20.        ]]
# [[14.11774794 14.14768581 13.69210412]
#  [15.20395368  0.         20.        ]
#  [20.         20.         20.        ]]
# [[14.14768581 13.69210412 14.99406213]
#  [15.21877154  0.         20.        ]
#  [20.         20.         20.        ]]
# [[13.69210412 14.99406213 20.        ]
#  [15.18770811  0.         20.        ]
#  [20.         20.         20.        ]]
# [[20.         14.79609983 15.18201835]
#  [20.          0.         20.        ]
#  [20.         20.          0.        ]]
# [[14.79609983 15.18201835 15.20643428]
#  [15.46917235  0.         20.        ]
#  [20.          0.          0.        ]]
# [[15.18201835 15.20643428 15.20439947]
#  [16.49137343  0.         20.        ]
#  [ 0.          0.          0.        ]]
# [[15.20643428 15.20439947 15.20395368]
#  [17.13867623  0.         20.        ]
#  [ 0.          0.          0.        ]]
# [[15.20439947 15.20395368 15.21877154]
#  [17.11534767  0.         20.        ]
#  [ 0.          0.          0.        ]]
# [[15.20395368 15.21877154 15.18770811]
#  [17.11573081  0.         20.        ]
#  [ 0.          0.          0.        ]]
# [[15.21877154 15.18770811 14.98478869]
#  [17.11629929  0.         20.        ]
#  [ 0.          0.         20.        ]]
# [[15.18770811 14.98478869 20.        ]
#  [16.42675146  0.         20.        ]
#  [ 0.         20.         20.        ]]
# [[20.         15.46917235 16.49137343]
#  [20.          0.          0.        ]
#  [20.         20.          0.        ]]
# [[15.46917235 16.49137343 17.13867623]
#  [16.09723588 63.75        0.        ]
#  [20.          0.          0.        ]]
# [[16.49137343 17.13867623 17.11534767]
#  [14.80796661 63.75        0.        ]
#  [ 0.          0.          0.        ]]
# [[17.13867623 17.11534767 17.11573081]
#  [15.4926932  63.75        0.        ]
#  [ 0.          0.          0.        ]]
# [[17.11534767 17.11573081 17.11629929]
#  [15.44706064 63.75        0.        ]
#  [ 0.          0.          0.        ]]
# [[17.11573081 17.11629929 16.42675146]
#  [15.44943134 63.75        0.        ]
#  [ 0.          0.          0.        ]]
# [[17.11629929 16.42675146 15.58695431]
#  [15.47335206 63.75       20.        ]
#  [ 0.          0.         20.        ]]
# [[16.42675146 15.58695431 20.        ]
#  [14.13147339  0.         20.        ]
#  [ 0.         20.         20.        ]]
# [[20.         16.09723588 14.80796661]
#  [20.          0.          0.        ]
#  [20.         20.         20.        ]]
# [[16.09723588 14.80796661 15.4926932 ]
#  [15.43685569 63.75        0.        ]
#  [20.         20.         20.        ]]
# [[14.80796661 15.4926932  15.44706064]
#  [13.53081477 63.75        0.        ]
#  [20.         20.         20.        ]]
# [[15.4926932  15.44706064 15.44943134]
#  [13.61992034 63.75        0.        ]
#  [20.         20.         20.        ]]
# [[15.44706064 15.44943134 15.47335206]
#  [13.59445384 63.75        0.        ]
#  [20.         20.         20.        ]]
# [[15.44943134 15.47335206 14.13147339]
#  [13.59601576 63.75        0.        ]
#  [20.         20.         20.        ]]
# [[15.47335206 14.13147339 15.60278243]
#  [13.64182056 63.75       20.        ]
#  [20.         20.         20.        ]]
# [[14.13147339 15.60278243 20.        ]
#  [12.93771056  0.         20.        ]
#  [20.         20.         20.        ]]
# [[20.         15.43685569 13.53081477]
#  [20.          0.         20.        ]
#  [20.         20.         20.        ]]
# [[15.43685569 13.53081477 13.61992034]
#  [14.80722717  0.         20.        ]
#  [20.         20.         20.        ]]
# [[13.53081477 13.61992034 13.59445384]
#  [15.21063815  0.         20.        ]
#  [20.         20.         20.        ]]
# [[13.61992034 13.59445384 13.59601576]
#  [15.26079906  0.         20.        ]
#  [20.         20.         20.        ]]
# [[13.59445384 13.59601576 13.64182056]
#  [15.25677773  0.         20.        ]
#  [20.         20.         20.        ]]
# [[13.59601576 13.64182056 12.93771056]
#  [15.2561545   0.         20.        ]
#  [20.         20.         20.        ]]
# [[13.64182056 12.93771056 15.02668527]
#  [15.27906923  0.         20.        ]
#  [20.         20.         20.        ]]
# [[12.93771056 15.02668527 20.        ]
#  [15.22839963  0.         20.        ]
#  [20.         20.         20.        ]]
